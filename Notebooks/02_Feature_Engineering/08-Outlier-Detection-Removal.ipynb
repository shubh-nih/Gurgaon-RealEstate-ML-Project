# %%
import pandas as pd
import numpy as n
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('gurgaon-cleaned-2.csv')

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.head(2)
# Out:
#   property_type                society      sector  price  price_per_sqft  \
# 0          flat  signature global park  sohna road   0.90          8036.0
# 1          flat            m3m skywalk   sector 74   2.25         13636.0
#
#      area                                       areaWithType  bedRoom  \
# 0  1120.0                 Built Up area: 1120 (104.05 sq.m.)        3
# 1  1650.0  Super Built up area 2038(189.34 sq.m.)Built Up...        3
#
#    bathroom balcony  floorNum facing   agePossession  super_built_up_area  \
# 0         2       0       2.0    NaN       Undefined                  NaN
# 1         3       2       9.0  South  Relatively New               2038.0
#
#    built_up_area  carpet_area  servant room  study room  pooja room  \
# 0         1120.0          NaN             0           0           0
# 1         1938.0       1650.0             1           0           0
#
#    store room  others  furnished_type  luxury_score
# 0           0       0               0            58
# 1           0       0               1           174

# %% [markdown]
# ## price

# %%
sns.displot(df['price'], kde = True, height = 6, aspect = 2)
plt.show()

# %%
plt.figure(figsize = (17, 7))
sns.boxplot(x = df['price'])
plt.show()

# %%
# calculate IQR
Q1 = df['price'].quantile(0.25)
Q3 = df['price'].quantile(0.75)
IQR = Q3 - Q1
# define bounds 
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
# filter data on the based of defined bounds
outliers = df[(df['price'] < lower_bound) | (df['price'] > upper_bound)]
# display the outliers stats
outlier_stats = outliers['price'].describe()

outlier_stats
# Out:
# count    426.000000
# mean       9.229202
# std        4.062636
# min        5.460000
# 25%        6.470000
# 50%        8.000000
# 75%       10.702500
# max       31.500000
# Name: price, dtype: float64

# %%
outliers.sort_values(by = 'price', ascending = False).head(20)
# Out:
#      property_type                                            society  \
# 3105         house  arjun marg/ sector- 26 phase- 1/ golf course road
# 1395         house                                        independent
# 784          house                                        independent
# 3039         house                                     dlf city plots
# 1674         house                                   suncity township
# 762          house                             emaar the palm springs
# 2859         house                                        independent
# 255          house                                 vipul tatvam villa
# 3460         house                                        independent
# 3478         house                             luxury dlf city floors
# 267          house                                     dlf city plots
# 1197         house                                 vipul tatvam villa
# 3603         house                                        independent
# 3572         house                                        independent
# 2010         house                                     dlf city plots
# 3491         house                                 emaar mgf marbella
# 1359         house                                        independent
# 2179         house                                 vipul tatvam villa
# 1846         house                                        independent
# 3319         house                                        independent
#
#          sector  price  price_per_sqft     area  \
# 3105  sector 26  31.50         35000.0   9000.0
# 1395  sector 43  27.50         24366.0  11286.0
# 784   sector 26  26.00         82540.0   3150.0
# 3039  sector 26  26.00         57206.0   4545.0
# 1674  sector 54  25.00         31111.0   8036.0
# 762   sector 54  24.00        600000.0    400.0
# 2859  sector 26  23.00         25556.0   9000.0
# 255   sector 48  22.00         26667.0   8250.0
# 3460  sector 26  20.00         44444.0   4500.0
# 3478  sector 26  20.00         48889.0   4091.0
# 267   sector 26  20.00         44265.0   4518.0
# 1197  sector 48  19.50         22222.0   8775.0
# 3603  sector 23  19.50         27083.0   7200.0
# 3572  sector 26  19.00         42222.0   4500.0
# 2010  sector 26  19.00         42054.0   4518.0
# 3491  sector 66  19.00         31666.0   6000.0
# 1359  sector 26  18.90         41833.0   4518.0
# 2179  sector 48  18.50         26428.0   7000.0
# 1846  sector 26  18.40          1859.0  98978.0
# 3319  sector 26  18.25         18250.0  10000.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 3105                       Plot area 1000(836.13 sq.m.)        7         9
# 1395                       Plot area 1254(1048.5 sq.m.)        6         7
# 784   Plot area 402(336.12 sq.m.)Built Up area: 400 ...       16        16
# 3039                        Plot area 505(422.24 sq.m.)        6         7
# 1674                       Plot area 1000(836.13 sq.m.)        4         4
# 762                          Plot area 400(37.16 sq.m.)        5         5
# 2859                       Plot area 1000(836.13 sq.m.)        4         4
# 255                        Plot area 1000(836.13 sq.m.)        5         6
# 3460                        Plot area 500(418.06 sq.m.)        5         7
# 3478                        Plot area 500(418.06 sq.m.)       16        16
# 267                         Plot area 502(419.74 sq.m.)       16        20
# 1197                        Plot area 975(815.22 sq.m.)        5         6
# 3603                         Plot area 800(668.9 sq.m.)        8         9
# 3572                        Plot area 500(418.06 sq.m.)        6         8
# 2010                        Plot area 502(419.74 sq.m.)        6         6
# 3491  Plot area 9000(836.13 sq.m.)Carpet area: 6000 ...        5         6
# 1359                        Plot area 502(419.74 sq.m.)        6         8
# 2179                       Plot area 7000(650.32 sq.m.)        4         4
# 1846  Plot area 502(419.74 sq.m.)Carpet area: 11000 ...        6         8
# 3319  Plot area 550(51.1 sq.m.)Carpet area: 10000 sq...        7         9
#
#      balcony  floorNum      facing   agePossession  super_built_up_area  \
# 3105      3+       3.0  North-East  Moderately Old                  NaN
# 1395      3+       3.0  North-East  Relatively New                  NaN
# 784       3+       4.0  North-West    New Property                  NaN
# 3039      3+       2.0  North-East    New Property                  NaN
# 1674      3+       2.0       North  Moderately Old                  NaN
# 762        2       1.0  North-East    Old Property                  NaN
# 2859      3+       2.0  South-West  Relatively New                  NaN
# 255        3       3.0         NaN  Moderately Old                  NaN
# 3460      3+       3.0        West  Relatively New                  NaN
# 3478      3+       4.0         NaN    New Property                  NaN
# 267       3+       4.0  North-East    New Property                  NaN
# 1197       3       2.0       North  Moderately Old                  NaN
# 3603      3+       2.0       North    New Property                  NaN
# 3572      3+       3.0        East  Moderately Old                  NaN
# 2010       3       2.0        East  Relatively New                  NaN
# 3491      3+       3.0  North-East  Relatively New                  NaN
# 1359       2       3.0  North-East  Relatively New                  NaN
# 2179       1       1.0         NaN  Moderately Old                  NaN
# 1846      3+       4.0       South  Relatively New                  NaN
# 3319      3+       4.0        East  Relatively New                  NaN
#
#       built_up_area  carpet_area  servant room  study room  pooja room  \
# 3105         9000.0          NaN             1           1           1
# 1395        11286.0          NaN             1           1           1
# 784           400.0        350.0             1           1           1
# 3039         4545.0          NaN             1           1           1
# 1674         1000.0          NaN             1           1           1
# 762           400.0          NaN             1           1           1
# 2859         9000.0          NaN             1           1           1
# 255          1000.0          NaN             1           0           0
# 3460         4500.0          NaN             1           0           1
# 3478          500.0          NaN             1           0           0
# 267          4518.0          NaN             1           1           1
# 1197         8775.0          NaN             1           1           1
# 3603         7200.0          NaN             1           1           1
# 3572         4500.0          NaN             1           1           1
# 2010         4518.0          NaN             1           1           0
# 3491            NaN       6000.0             1           0           1
# 1359         4518.0          NaN             1           1           1
# 2179         7000.0          NaN             0           0           0
# 1846            NaN      11000.0             1           0           1
# 3319            NaN      10000.0             1           1           1
#
#       store room  others  furnished_type  luxury_score
# 3105           1       0               2            74
# 1395           0       1               1            42
# 784            1       0               2            72
# 3039           0       1               1           138
# 1674           1       0               0             0
# 762            0       0               1           122
# 2859           1       0               1           145
# 255            0       0               0            54
# 3460           0       0               2            97
# 3478           0       0               1            31
# 267            1       0               1           153
# 1197           1       0               1           110
# 3603           0       0               0           122
# 3572           1       0               1           103
# 2010           0       0               1           121
# 3491           1       0               1           110
# 1359           1       0               1           120
# 2179           0       0               0            30
# 1846           1       0               1            60
# 3319           1       0               1            77

# %% [markdown]
# on the basis of price cols, we can say some are genuine errors and some are data error

# %% [markdown]
# ## price_per_sqft

# %%
sns.displot(df['price_per_sqft'], kde = True, height = 6, aspect = 2)
plt.show()

# %%
plt.figure(figsize = (17, 7))
sns.boxplot(x = df['price_per_sqft'])
plt.show()

# %%
# calculate IQR
Q1 = df['price_per_sqft'].quantile(0.25)
Q3 = df['price_per_sqft'].quantile(0.75)
IQR = Q3 - Q1
# define bounds 
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
# filter data on the based of defined bounds
outliers_sqft = df[(df['price_per_sqft'] < lower_bound) | (df['price_per_sqft'] > upper_bound)]
# display the outliers stats
outlier_stats_sqft = outliers_sqft['price_per_sqft'].describe()

outlier_stats_sqft
# Out:
# count       354.000000
# mean      53053.847458
# std       61294.368249
# min       24510.000000
# 25%       28270.250000
# 50%       33628.500000
# 75%       42159.000000
# max      600000.000000
# Name: price_per_sqft, dtype: float64

# %%
outliers_sqft.sort_values(by = 'price_per_sqft', ascending = False).head(30)
# Out:
#      property_type                      society     sector  price  \
# 762          house       emaar the palm springs  sector 54  24.00
# 3121         house       dlf city plots phase 2  sector 25  10.00
# 1631         house                  independent  sector 12   6.00
# 2943         house                        ansal  sector 43   1.85
# 3195         house               uppal southend  sector 49   6.75
# 3411         house  unitech nirvana birch court  sector 50   7.10
# 2480         house                  independent  sector 57   8.00
# 2499         house       dlf city plots phase 2  sector 25  10.50
# 1911         house          huda plot sector 38  sector 38   4.30
# 3293         house                  independent  sector 56   1.45
# 838          house       unitech deerwood chase  sector 50   8.45
# 1310         house                  independent  sector 54   3.75
# 2714         house                  independent  sector 38   8.00
# 10           house                  independent  sector 24  10.00
# 1485         house                  independent  sector 17   3.50
# 3636         house                dlf the grove  sector 54   5.70
# 2918         house           vipul tatvam villa  sector 48   7.25
# 2372          flat           ambience caitriona  sector 24  14.00
# 2749         house            vatika india next  sector 82   7.00
# 1411         house                   ardee city  sector 52   5.50
# 1493         house     unitech uniworld resorts  sector 33  10.00
# 957          house         eros rosewood villas  sector 49   2.75
# 3295         house     unitech uniworld resorts  sector 33   9.50
# 2226         house                  independent  sector 23   2.80
# 1623         house                  independent   sector 3   0.75
# 3410         house                  independent  sector 12   3.50
# 1258         house         bhim nagar, sector 6   sector 6   0.85
# 237          house                  independent  sector 28   4.50
# 3541         house                    rk excelo  sector 12   0.60
# 2022         house                  independent   sector 4   0.60
#
#       price_per_sqft   area  \
# 762         600000.0  400.0
# 3121        400000.0  250.0
# 1631        315789.0  190.0
# 2943        308333.0   60.0
# 3195        290948.0  232.0
# 3411        283333.0  251.0
# 2480        266666.0  300.0
# 2499        261194.0  402.0
# 1911        245398.0  175.0
# 3293        241666.0   60.0
# 838         235376.0  359.0
# 1310        234375.0  160.0
# 2714        230547.0  347.0
# 10          229885.0  435.0
# 1485        218750.0  160.0
# 3636        211111.0  270.0
# 2918        201388.0  360.0
# 2372        200000.0  700.0
# 2749        194444.0  360.0
# 1411        183333.0  300.0
# 1493        181818.0  550.0
# 957         178571.0  154.0
# 3295        173992.0  546.0
# 2226        161849.0  173.0
# 1623        138888.0   54.0
# 3410        133079.0  263.0
# 1258        126865.0   67.0
# 237         125000.0  360.0
# 3541        120000.0   50.0
# 2022        105263.0   57.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 762                          Plot area 400(37.16 sq.m.)        5         5
# 3121                         Plot area 250(23.23 sq.m.)       12        12
# 1631  Plot area 190(17.65 sq.m.)Carpet area: 1600 sq...        9         6
# 2943                           Plot area 60(5.57 sq.m.)        8         8
# 3195                         Plot area 232(21.55 sq.m.)       12        12
# 3411                          Plot area 240(22.3 sq.m.)        3         3
# 2480                         Plot area 300(27.87 sq.m.)        5         4
# 2499                         Plot area 402(37.35 sq.m.)        4         4
# 1911  Plot area 163(15.14 sq.m.)Built Up area: 145 s...       13        13
# 3293                           Plot area 60(5.57 sq.m.)        4         4
# 838                          Plot area 359(33.35 sq.m.)        3         3
# 1310                         Plot area 160(14.86 sq.m.)        4         4
# 2714  Built Up area: 347 (32.24 sq.m.)Carpet area: 2...       10        10
# 10                       Carpet area: 435 (40.41 sq.m.)        8        10
# 1485                   Built Up area: 160 (14.86 sq.m.)        6         6
# 3636                   Built Up area: 270 (25.08 sq.m.)        4         4
# 2918                         Plot area 360(33.45 sq.m.)        4         4
# 2372                   Built Up area: 700 (65.03 sq.m.)        4         5
# 2749  Plot area 360(33.45 sq.m.)Built Up area: 3900 ...        4         4
# 1411                         Plot area 300(27.87 sq.m.)        9         9
# 1493                          Plot area 550(51.1 sq.m.)        5         6
# 957   Plot area 154(14.31 sq.m.)Carpet area: 1650 sq...        3         3
# 3295                         Plot area 546(50.73 sq.m.)        6         6
# 2226  Plot area 173(16.07 sq.m.)Built Up area: 160 s...        5         5
# 1623                           Plot area 54(5.02 sq.m.)        2         1
# 3410  Plot area 263(24.43 sq.m.)Built Up area: 4800 ...        8         8
# 1258                           Plot area 67(6.22 sq.m.)        5         2
# 237                    Built Up area: 360 (33.45 sq.m.)        4         4
# 3541  Plot area 50(4.65 sq.m.)Built Up area: 30 sq.f...        5         3
# 2022                            Plot area 57(5.3 sq.m.)        3         3
#
#      balcony  floorNum      facing   agePossession  super_built_up_area  \
# 762        2       1.0  North-East    Old Property                  NaN
# 3121      3+       4.0       North  Relatively New                  NaN
# 1631       2       2.0  North-East    Old Property                  NaN
# 2943      3+       5.0  North-West  Relatively New                  NaN
# 3195      3+       NaN        West  Moderately Old                  NaN
# 3411       3       1.0        East  Moderately Old                  NaN
# 2480       3       2.0       North  Relatively New                  NaN
# 2499       2       2.0        East    Old Property                  NaN
# 1911      3+       5.0  North-West  Relatively New                  NaN
# 3293      3+       4.0        East  Relatively New                  NaN
# 838        2       2.0  North-East    Old Property                  NaN
# 1310       3       3.0        East  Moderately Old                  NaN
# 2714      3+       1.0       North       Undefined                  NaN
# 10        3+       1.0        West       Undefined                  NaN
# 1485      3+       3.0  North-West       Undefined                  NaN
# 3636       0       1.0         NaN       Undefined                  NaN
# 2918       3       2.0         NaN  Relatively New                  NaN
# 2372       3       3.0        East       Undefined                  NaN
# 2749      3+       3.0  North-East  Relatively New                  NaN
# 1411      3+       3.0       South  Moderately Old                  NaN
# 1493       3       4.0  North-East    New Property                  NaN
# 957        1       2.0  North-West    Old Property                  NaN
# 3295      3+       3.0  North-East  Moderately Old                  NaN
# 2226      3+       2.0  North-East    Old Property                  NaN
# 1623       0       1.0         NaN    Old Property                  NaN
# 3410      3+       3.0  South-East  Relatively New                  NaN
# 1258       2       1.0         NaN    Old Property                  NaN
# 237        0       4.0         NaN       Undefined                  NaN
# 3541       2       3.0       North  Moderately Old                  NaN
# 2022       1       2.0         NaN    Old Property                  NaN
#
#       built_up_area  carpet_area  servant room  study room  pooja room  \
# 762           400.0          NaN             1           1           1
# 3121          250.0          NaN             1           1           0
# 1631            NaN       1600.0             0           0           0
# 2943           60.0          NaN             0           0           0
# 3195          232.0          NaN             1           1           1
# 3411          240.0          NaN             1           0           0
# 2480          300.0          NaN             1           1           1
# 2499          402.0          NaN             1           0           1
# 1911          145.0          NaN             0           0           0
# 3293           60.0          NaN             0           0           0
# 838           359.0          NaN             1           1           0
# 1310          160.0          NaN             1           0           0
# 2714          347.0        215.0             0           0           0
# 10              NaN        435.0             0           0           0
# 1485          160.0          NaN             0           0           0
# 3636          270.0          NaN             0           0           0
# 2918          360.0          NaN             1           1           1
# 2372          700.0          NaN             0           0           0
# 2749         3900.0       3743.0             1           0           0
# 1411          300.0          NaN             1           0           1
# 1493          550.0          NaN             1           1           0
# 957             NaN       1650.0             0           0           0
# 3295          546.0          NaN             0           0           0
# 2226          160.0        150.0             0           0           1
# 1623           54.0          NaN             0           0           0
# 3410         4800.0       4400.0             1           1           1
# 1258           67.0          NaN             0           0           1
# 237           360.0          NaN             0           0           0
# 3541           30.0         15.0             0           0           0
# 2022           57.0          NaN             0           0           0
#
#       store room  others  furnished_type  luxury_score
# 762            0       0               1           122
# 3121           0       0               1           114
# 1631           0       0               0             0
# 2943           0       0               0            53
# 3195           0       1               1            49
# 3411           0       0               0            49
# 2480           0       0               0            21
# 2499           0       0               1            91
# 1911           0       0               2             7
# 3293           1       0               0            70
# 838            0       0               1           102
# 1310           0       0               1            13
# 2714           0       0               0             0
# 10             0       0               0             0
# 1485           0       0               0             0
# 3636           0       0               0            46
# 2918           1       0               1           103
# 2372           0       0               0             0
# 2749           0       0               2           105
# 1411           0       1               1            26
# 1493           0       0               0            26
# 957            0       1               1            80
# 3295           0       0               1            40
# 2226           0       0               1            74
# 1623           0       0               0             0
# 3410           0       0               2            77
# 1258           0       0               0            29
# 237            0       0               0             0
# 3541           0       1               0             0
# 2022           0       1               0             0

# %% [markdown]
# price per sqft is calculated when price is divided by area (sqft). area should be in sqft but here area is in sq yard

# %%
# convert area which is in sq yard in sqft
outliers_sqft['area'] = outliers_sqft['area'].apply(lambda x: x * 9 if x < 1000 else x)
# Out:
# C:\Users\Shubham\AppData\Local\Temp\ipykernel_15772\3271010852.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outliers_sqft['area'] = outliers_sqft['area'].apply(lambda x: x * 9 if x < 1000 else x)

# %%
# recalculate price per sqft on the updated area (sqft)
outliers_sqft['price_per_sqft'] = round(outliers_sqft['price']*10000000/outliers_sqft['area'])
# Out:
# C:\Users\Shubham\AppData\Local\Temp\ipykernel_15772\701523487.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outliers_sqft['price_per_sqft'] = round(outliers_sqft['price']*10000000/outliers_sqft['area'])

# %%
# value reduced
outliers_sqft['price_per_sqft'].describe()
# Out:
# count      354.000000
# mean     29224.621469
# std      12547.929157
# min       2723.000000
# 25%      25562.000000
# 50%      29870.500000
# 75%      35549.500000
# max      82540.000000
# Name: price_per_sqft, dtype: float64

# %%
df.update(outliers_sqft)

# %%
sns.displot(df['price_per_sqft'], kde = True, height = 6, aspect = 2)
plt.show()

# %%
plt.figure(figsize = (17, 7))
sns.boxplot(x = df['price_per_sqft'])
plt.show()

# %%
df[df['price_per_sqft'] > 50000]
# Out:
#      property_type                       society      sector  price  \
# 313          house                  malibu towne   sector 47   8.50
# 419          house            emaar mgf marbella   sector 66  18.00
# 696          house  project housing board colony   sector 31   8.00
# 762          house        emaar the palm springs   sector 54  24.00
# 784          house                   independent   sector 26  26.00
# 829          house                           nul   sector 28  12.50
# 949          house        emaar the palm springs   sector 54  14.00
# 1041         house                unitech escape   sector 50  10.80
# 2843         house                   independent   sector 26  14.75
# 2896          flat                unitech vistas   sector 70   9.00
# 3039         house                dlf city plots   sector 26  26.00
# 3599         house                   independent   sector 25  16.00
# 3682         house            cloudnine cottages  sohna road   5.50
#
#       price_per_sqft    area  \
# 313          53125.0  1600.0
# 419          55556.0  3240.0
# 696          63492.0  1260.0
# 762          66667.0  3600.0
# 784          82540.0  3150.0
# 829          51440.0  2430.0
# 949          62222.0  2250.0
# 1041         60000.0  1800.0
# 2843         51864.0  2844.0
# 2896         57508.0  1565.0
# 3039         57206.0  4545.0
# 3599         59259.0  2700.0
# 3682         55000.0  1000.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 313                  Built Up area: 1600 (148.64 sq.m.)       12        12
# 419                         Plot area 360(301.01 sq.m.)        4         4
# 696                   Built Up area: 140 (117.06 sq.m.)        2         1
# 762                          Plot area 400(37.16 sq.m.)        5         5
# 784   Plot area 402(336.12 sq.m.)Built Up area: 400 ...       16        16
# 829                         Plot area 270(225.75 sq.m.)       16        17
# 949                         Plot area 250(209.03 sq.m.)        4         5
# 1041  Plot area 290(242.48 sq.m.)Built Up area: 250 ...        4         4
# 2843                        Plot area 316(264.22 sq.m.)       16        20
# 2896                 Built Up area: 1565 (145.39 sq.m.)        3         3
# 3039                        Plot area 505(422.24 sq.m.)        6         7
# 3599  Plot area 350(292.64 sq.m.)Built Up area: 325 ...       16        16
# 3682                         Plot area 1000(92.9 sq.m.)        3         3
#
#      balcony  floorNum      facing   agePossession  super_built_up_area  \
# 313       3+       4.0       North    New Property                  NaN
# 419       3+       3.0        East  Moderately Old                  NaN
# 696        0       1.0         NaN       Undefined                  NaN
# 762        2       1.0  North-East    Old Property                  NaN
# 784       3+       4.0  North-West    New Property                  NaN
# 829       3+       4.0       South  Relatively New                  NaN
# 949       3+       2.0       North    Old Property                  NaN
# 1041       3       2.0       North  Relatively New                  NaN
# 2843      3+       4.0        East    New Property                  NaN
# 2896       0       7.0         NaN       Undefined                  NaN
# 3039      3+       2.0  North-East    New Property                  NaN
# 3599      3+       4.0        West    New Property                  NaN
# 3682       0       1.0         NaN  Moderately Old                  NaN
#
#       built_up_area  carpet_area  servant room  study room  pooja room  \
# 313          1600.0          NaN             0           0           0
# 419          3240.0          NaN             1           1           1
# 696           140.0          NaN             0           0           0
# 762           400.0          NaN             1           1           1
# 784           400.0        350.0             1           1           1
# 829          2430.0          NaN             1           1           1
# 949          2250.0          NaN             1           1           0
# 1041          250.0        200.0             1           1           1
# 2843         2844.0          NaN             1           1           1
# 2896         1565.0          NaN             0           0           0
# 3039         4545.0          NaN             1           1           1
# 3599          325.0        300.0             1           1           1
# 3682         1000.0          NaN             0           0           0
#
#       store room  others  furnished_type  luxury_score
# 313            0       0               1            99
# 419            0       0               2            75
# 696            0       0               0             0
# 762            0       0               1           122
# 784            1       0               2            72
# 829            0       1               2           137
# 949            0       0               1           160
# 1041           1       0               1           103
# 2843           1       0               1           153
# 2896           0       0               0             0
# 3039           0       1               1           138
# 3599           1       0               2            72
# 3682           0       0               0             0

# %%
df[df['price_per_sqft'] > 50000].shape[0]
# Out:
# 13

# %%
# drop those 13 col considering as outliers
df = df[df['price_per_sqft'] <= 50000]

# %%
plt.figure(figsize = (17, 7))
sns.boxplot(x = df['price_per_sqft'])
plt.show()

# %% [markdown]
# ## area

# %%
sns.displot(df['area'], kde = True, height = 6, aspect = 2)
plt.show()

# %%
plt.figure(figsize = (17, 7))
sns.boxplot(x = df['area'])
plt.show()

# %% [markdown]
# extreme outliers as the graphs show data is fully right skewed

# %%
df['area'].describe()
# Out:
# count      3657.000000
# mean       2705.527755
# std       18140.845847
# min         145.000000
# 25%        1261.000000
# 50%        1750.000000
# 75%        2343.000000
# max      642857.000000
# Name: area, dtype: float64

# %%
df[df['area'] > 100000]
# Out:
#      property_type                    society      sector  price  \
# 314           flat  signature global solera 2  sector 107   0.51
# 790          house                independent   sector 50   5.00
# 1004          flat      signature the roselia   sector 95   0.45
# 2898          flat            ramsons kshitij   sector 95   0.31
#
#       price_per_sqft      area                          areaWithType  bedRoom  \
# 314              9.0  566667.0  Carpet area: 514396 (47788.95 sq.m.)        2
# 790            232.0  215517.0            Plot area 2(1011.71 sq.m.)        6
# 1004             7.0  642857.0  Carpet area: 569243 (52884.41 sq.m.)        2
# 2898             5.0  620000.0   Carpet area: 607936 (56479.1 sq.m.)        2
#
#       bathroom balcony  floorNum      facing   agePossession  \
# 314          2       1       3.0       North    New Property
# 790          5      3+       2.0         NaN    New Property
# 1004         2       2       2.0  South-West    New Property
# 2898         2       1       1.0  North-East  Relatively New
#
#       super_built_up_area  built_up_area  carpet_area  servant room  \
# 314                   NaN            NaN     514396.0             0
# 790                   NaN            2.0          NaN             1
# 1004                  NaN            NaN     569243.0             0
# 2898                  NaN            NaN     607936.0             0
#
#       study room  pooja room  store room  others  furnished_type  luxury_score
# 314            0           0           0       0               0            44
# 790            1           1           0       1               1             0
# 1004           0           0           0       0               0            76
# 2898           1           0           0       1               0            65

# %% [markdown]
# prices are less yet the area is very big. considering as a outliers and droping it

# %%
df = df[df['area'] < 100000]

# %%
plt.figure(figsize = (17, 7))
sns.boxplot(x = df['area'])
plt.show()

# %%
df[df['area'] > 10000].sort_values(by = 'area', ascending = False)
# Out:
#      property_type                    society      sector  price  \
# 1846         house                independent   sector 26  18.40
# 2556         house  ganpati heights apartment   sector 11   1.25
# 2351          flat                 rof ananda   sector 95   0.38
# 1934          flat                 rof ananda   sector 95   0.38
# 1617         house      dlf city plot phase 4   sector 28  13.00
# 405           flat              pyramid elite   sector 86   0.46
# 1211          flat                 rof ananda   sector 95   0.33
# 273           flat      signature the serenas  sohna road   0.28
# 1452         house                independent   sector 25   7.30
# 662           flat            ramsons kshitij   sector 95   0.24
# 1441          flat                 rof ananda   sector 95   0.21
# 1581         house                independent   sector 57   6.25
# 1917         house                independent   sector 43   5.50
# 1113          flat                 godrej air   sector 85   2.50
# 3666         house       unitech aspen greens   sector 50   6.95
# 3314         house                independent    sector 4   0.85
# 1288          flat                godrej icon   sector 88   1.75
# 1395         house                independent   sector 43  27.50
# 2412          flat             m3m golfestate   sector 65  13.20
# 31           house                independent  sohna road   5.50
#
#       price_per_sqft     area  \
# 1846          1859.0  98978.0
# 2556           151.0  82781.0
# 2351            58.0  65517.0
# 1934            58.0  65517.0
# 1617          1992.0  65261.0
# 405             79.0  58228.0
# 1211            60.0  55000.0
# 273             57.0  49123.0
# 1452          1560.0  46795.0
# 662             53.0  45283.0
# 1441            61.0  34426.0
# 1581          2778.0  22498.0
# 1917          2716.0  20250.0
# 1113          1379.0  18129.0
# 3666          4490.0  15479.0
# 3314           630.0  13492.0
# 1288          1384.0  12645.0
# 1395         24366.0  11286.0
# 2412         12000.0  11000.0
# 31            5093.0  10799.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 1846  Plot area 502(419.74 sq.m.)Carpet area: 11000 ...        6         8
# 2556                       Plot area 115(7692.86 sq.m.)       10         6
# 2351                 Carpet area: 64529 (5994.94 sq.m.)        2         2
# 1934                 Carpet area: 64412 (5984.07 sq.m.)        3         2
# 1617                  Carpet area: 7250 (6061.92 sq.m.)       10        10
# 405                  Carpet area: 58141 (5401.48 sq.m.)        2         2
# 1211                 Carpet area: 54917 (5101.96 sq.m.)        2         2
# 273                  Carpet area: 48811 (4534.69 sq.m.)        1         1
# 1452  Plot area 215(179.77 sq.m.)Built Up area: 5800...        9         9
# 662                  Carpet area: 45966 (4270.38 sq.m.)        2         2
# 1441                 Carpet area: 34401 (3195.96 sq.m.)        1         1
# 1581  Plot area 3100(2591.99 sq.m.)Built Up area: 26...        9         9
# 1917  Plot area 215(179.77 sq.m.)Built Up area: 2850...        8         7
# 1113                 Carpet area: 18122 (1683.59 sq.m.)        4         5
# 3666  Plot area 240(200.67 sq.m.)Built Up area: 2160...        3         3
# 3314                      Plot area 1500(1254.19 sq.m.)        3         3
# 1288                               Carpet area: 1175.11        3         3
# 1395                       Plot area 1254(1048.5 sq.m.)        6         7
# 2412                 Carpet area: 11000 (1021.93 sq.m.)        4         4
# 31    Plot area 1200(1003.35 sq.m.)Built Up area: 35...        3         3
#
#      balcony  floorNum      facing       agePossession  super_built_up_area  \
# 1846      3+       4.0       South      Relatively New                  NaN
# 2556       2       3.0  South-East        Old Property                  NaN
# 2351       2      10.0        East        New Property                  NaN
# 1934       1      12.0       North      Relatively New                  NaN
# 1617      3+       1.0         NaN           Undefined                  NaN
# 405        1       0.0         NaN  Under Construction                  NaN
# 1211       1      13.0  South-West      Relatively New                  NaN
# 273        2       1.0  North-West      Relatively New                  NaN
# 1452       2       3.0  North-West      Relatively New                  NaN
# 662        1      10.0  North-West      Relatively New                  NaN
# 1441       1      13.0       North      Relatively New                  NaN
# 1581      3+       3.0  North-East        New Property                  NaN
# 1917      3+       3.0        East      Moderately Old                  NaN
# 1113      3+      16.0  North-East           Undefined                  NaN
# 3666       1       2.0  North-East      Moderately Old                  NaN
# 3314       1       1.0       North      Relatively New                  NaN
# 1288      3+       6.0         NaN        New Property                  NaN
# 1395      3+       3.0  North-East      Relatively New                  NaN
# 2412       3      13.0       North      Moderately Old                  NaN
# 31        3+       2.0        West      Moderately Old                  NaN
#
#       built_up_area  carpet_area  servant room  study room  pooja room  \
# 1846            NaN     11000.00             1           0           1
# 2556          115.0          NaN             0           0           0
# 2351            NaN     64529.00             0           1           0
# 1934            NaN     64412.00             0           0           0
# 1617            NaN      7250.00             0           0           0
# 405             NaN     58141.00             0           0           0
# 1211            NaN     54917.00             0           0           0
# 273             NaN     48811.00             0           1           0
# 1452         5800.0      5200.00             1           0           0
# 662             NaN     45966.00             0           0           0
# 1441            NaN     34401.00             0           0           0
# 1581         2660.0      2500.00             1           0           0
# 1917         2850.0      2250.00             1           1           1
# 1113            NaN     18122.00             0           1           1
# 3666         2160.0      1720.00             1           0           0
# 3314        13500.0          NaN             0           0           0
# 1288            NaN      1175.11             0           0           0
# 1395        11286.0          NaN             1           1           1
# 2412            NaN     11000.00             1           0           0
# 31           3500.0          NaN             1           1           1
#
#       store room  others  furnished_type  luxury_score
# 1846           1       0               1            60
# 2556           0       1               0             7
# 2351           0       0               0            15
# 1934           0       0               0            51
# 1617           0       0               0             0
# 405            0       0               0            15
# 1211           0       0               0            37
# 273            0       0               0            37
# 1452           1       0               1           109
# 662            0       1               0            33
# 1441           0       0               0            68
# 1581           0       0               1            61
# 1917           0       1               1           123
# 1113           0       1               1            44
# 3666           0       0               0           160
# 3314           0       1               0             0
# 1288           0       0               0            55
# 1395           0       1               1            42
# 2412           0       0               0            60
# 31             0       1               0            49

# %% [markdown]
# 2351, 1934, 405, 1211, 273, 662, 1441, 3314, these indices highlight outlier properties with data errors, such as incorrect price and bedroom are too less as compared to area

# %%
df.drop(index = [2351, 1934, 405, 1211, 273, 662, 1441, 3314], inplace = True)

# %%
df[df['area'] > 10000].sort_values(by = 'area', ascending = False)
# Out:
#      property_type                    society      sector  price  \
# 1846         house                independent   sector 26  18.40
# 2556         house  ganpati heights apartment   sector 11   1.25
# 1617         house      dlf city plot phase 4   sector 28  13.00
# 1452         house                independent   sector 25   7.30
# 1581         house                independent   sector 57   6.25
# 1917         house                independent   sector 43   5.50
# 1113          flat                 godrej air   sector 85   2.50
# 3666         house       unitech aspen greens   sector 50   6.95
# 1288          flat                godrej icon   sector 88   1.75
# 1395         house                independent   sector 43  27.50
# 2412          flat             m3m golfestate   sector 65  13.20
# 31           house                independent  sohna road   5.50
#
#       price_per_sqft     area  \
# 1846          1859.0  98978.0
# 2556           151.0  82781.0
# 1617          1992.0  65261.0
# 1452          1560.0  46795.0
# 1581          2778.0  22498.0
# 1917          2716.0  20250.0
# 1113          1379.0  18129.0
# 3666          4490.0  15479.0
# 1288          1384.0  12645.0
# 1395         24366.0  11286.0
# 2412         12000.0  11000.0
# 31            5093.0  10799.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 1846  Plot area 502(419.74 sq.m.)Carpet area: 11000 ...        6         8
# 2556                       Plot area 115(7692.86 sq.m.)       10         6
# 1617                  Carpet area: 7250 (6061.92 sq.m.)       10        10
# 1452  Plot area 215(179.77 sq.m.)Built Up area: 5800...        9         9
# 1581  Plot area 3100(2591.99 sq.m.)Built Up area: 26...        9         9
# 1917  Plot area 215(179.77 sq.m.)Built Up area: 2850...        8         7
# 1113                 Carpet area: 18122 (1683.59 sq.m.)        4         5
# 3666  Plot area 240(200.67 sq.m.)Built Up area: 2160...        3         3
# 1288                               Carpet area: 1175.11        3         3
# 1395                       Plot area 1254(1048.5 sq.m.)        6         7
# 2412                 Carpet area: 11000 (1021.93 sq.m.)        4         4
# 31    Plot area 1200(1003.35 sq.m.)Built Up area: 35...        3         3
#
#      balcony  floorNum      facing   agePossession  super_built_up_area  \
# 1846      3+       4.0       South  Relatively New                  NaN
# 2556       2       3.0  South-East    Old Property                  NaN
# 1617      3+       1.0         NaN       Undefined                  NaN
# 1452       2       3.0  North-West  Relatively New                  NaN
# 1581      3+       3.0  North-East    New Property                  NaN
# 1917      3+       3.0        East  Moderately Old                  NaN
# 1113      3+      16.0  North-East       Undefined                  NaN
# 3666       1       2.0  North-East  Moderately Old                  NaN
# 1288      3+       6.0         NaN    New Property                  NaN
# 1395      3+       3.0  North-East  Relatively New                  NaN
# 2412       3      13.0       North  Moderately Old                  NaN
# 31        3+       2.0        West  Moderately Old                  NaN
#
#       built_up_area  carpet_area  servant room  study room  pooja room  \
# 1846            NaN     11000.00             1           0           1
# 2556          115.0          NaN             0           0           0
# 1617            NaN      7250.00             0           0           0
# 1452         5800.0      5200.00             1           0           0
# 1581         2660.0      2500.00             1           0           0
# 1917         2850.0      2250.00             1           1           1
# 1113            NaN     18122.00             0           1           1
# 3666         2160.0      1720.00             1           0           0
# 1288            NaN      1175.11             0           0           0
# 1395        11286.0          NaN             1           1           1
# 2412            NaN     11000.00             1           0           0
# 31           3500.0          NaN             1           1           1
#
#       store room  others  furnished_type  luxury_score
# 1846           1       0               1            60
# 2556           0       1               0             7
# 1617           0       0               0             0
# 1452           1       0               1           109
# 1581           0       0               1            61
# 1917           0       1               1           123
# 1113           0       1               1            44
# 3666           0       0               0           160
# 1288           0       0               0            55
# 1395           0       1               1            42
# 2412           0       0               0            60
# 31             0       1               0            49

# %%
# Correcting incorrect 'area' data with their built-up/carpet areas
df.loc[2556, 'area'] = 115*9
df.loc[1617, 'area'] = 7250
df.loc[1452, 'area'] = 5800
df.loc[1581, 'area'] = 2660
df.loc[1917, 'area'] = 2850
df.loc[1113, 'area'] = 1812
df.loc[3666, 'area'] = 2160
df.loc[1288, 'area'] = 1175

# %%
sns.displot(df['area'], kde = True, height = 6, aspect = 2)
plt.show()

# %%
plt.figure(figsize = (17, 7))
sns.boxplot(x = df['area'])
plt.show()

# %%
df[df['area'] > 10000].sort_values(by = 'area', ascending = False)
# Out:
#      property_type         society      sector  price  price_per_sqft  \
# 1846         house     independent   sector 26   18.4          1859.0
# 1395         house     independent   sector 43   27.5         24366.0
# 2412          flat  m3m golfestate   sector 65   13.2         12000.0
# 31           house     independent  sohna road    5.5          5093.0
#
#          area                                       areaWithType  bedRoom  \
# 1846  98978.0  Plot area 502(419.74 sq.m.)Carpet area: 11000 ...        6
# 1395  11286.0                       Plot area 1254(1048.5 sq.m.)        6
# 2412  11000.0                 Carpet area: 11000 (1021.93 sq.m.)        4
# 31    10799.0  Plot area 1200(1003.35 sq.m.)Built Up area: 35...        3
#
#       bathroom balcony  floorNum      facing   agePossession  \
# 1846         8      3+       4.0       South  Relatively New
# 1395         7      3+       3.0  North-East  Relatively New
# 2412         4       3      13.0       North  Moderately Old
# 31           3      3+       2.0        West  Moderately Old
#
#       super_built_up_area  built_up_area  carpet_area  servant room  \
# 1846                  NaN            NaN      11000.0             1
# 1395                  NaN        11286.0          NaN             1
# 2412                  NaN            NaN      11000.0             1
# 31                    NaN         3500.0          NaN             1
#
#       study room  pooja room  store room  others  furnished_type  luxury_score
# 1846           0           1           1       0               1            60
# 1395           1           1           0       1               1            42
# 2412           0           0           0       0               0            60
# 31             1           1           0       1               0            49

# %% [markdown]
# remove index 1846 identified as outliers as area is 98000+

# %%
df.drop(index = 1846, inplace = True)

# %%
df['area'].describe()
# Out:
# count     3644.000000
# mean      1949.619649
# std       1215.900119
# min        145.000000
# 25%       1260.000000
# 50%       1745.000000
# 75%       2325.000000
# max      11286.000000
# Name: area, dtype: float64

# %%
sns.displot(df['area'], kde = True, height = 6, aspect = 2)
plt.show()

# %%
plt.figure(figsize = (17, 7))
sns.boxplot(x = df['area'])
plt.show()

# %%
# improved
df['area'].describe()
# Out:
# count     3644.000000
# mean      1949.619649
# std       1215.900119
# min        145.000000
# 25%       1260.000000
# 50%       1745.000000
# 75%       2325.000000
# max      11286.000000
# Name: area, dtype: float64

# %% [markdown]
# ## bedroom

# %%
custom_bins = [0, 3, 6, 9, 12, 15, 18, 21]
sns.displot(df['bedRoom'], kde = True, height = 6, aspect = 2, bins = custom_bins)
plt.show()

# %%
plt.figure(figsize = (17, 7))
sns.boxplot(x = df['bedRoom'])
plt.show()

# %%
df['bedRoom'].describe()
# Out:
# count    3644.000000
# mean        3.333699
# std         1.828363
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max        21.000000
# Name: bedRoom, dtype: float64

# %%
df[df['bedRoom'] > 10].sort_values(by = 'bedRoom', ascending = False)
# Out:
#      property_type                      society      sector  price  \
# 2122         house                  independent   sector 54   5.00
# 3341         house                  independent   sector 43   4.50
# 3030         house                  independent   sector 17   3.87
# 2335         house                  independent   sector 17   3.93
# 848          house                  independent   sector 76   5.50
# 1756         house                private house   sector 55   7.05
# 3417         house                  independent   sector 40  12.00
# 3294         house                  independent   sector 56   9.19
# 3478         house       luxury dlf city floors   sector 26  20.00
# 329          house                  independent   sector 11   4.50
# 1265         house                  independent   sector 56  12.39
# 589          house                  independent   sector 43  13.50
# 267          house               dlf city plots   sector 26  20.00
# 1374         house                  independent   sector 24   3.20
# 1911         house          huda plot sector 38   sector 38   4.30
# 2469         house                  independent   sector 28  11.00
# 2611         house                  independent  sector 104   0.80
# 2056         house       dlf city plots phase 3   sector 24   5.00
# 65           house                  independent   sector 27   8.25
# 99           house                  independent   sector 13   0.50
# 288          house             dlf city phase 1   sector 26   9.25
# 1047         house                  independent   sector 26   8.49
# 844          house                  independent   sector 26  10.50
# 413          house                  independent   sector 40   9.50
# 815          house                  independent   sector 46   6.50
# 356          house    floor wise designer kothi   sector 25  13.00
# 1825         house       luxury dlf city floors   sector 26   8.25
# 1415         house                  independent   sector 56  11.95
# 1392         house                  independent   sector 56  11.50
# 2328         house                  independent   sector 55   7.49
# 2249         house                  independent   sector 43   3.00
# 2167         house                  independent   sector 43   2.20
# 1946         house                  independent   sector 14   8.00
# 1519         house                  independent   sector 43   7.50
# 1634         house                  independent   sector 31   9.25
# 1663         house               uppal southend   sector 49   6.75
# 2583         house                  independent   sector 57   6.95
# 3323         house       laxmi garden sector-11   sector 11   1.50
# 3121         house       dlf city plots phase 2   sector 25  10.00
# 2660         house                  independent   sector 46   6.81
# 2784         house                  independent   sector 47   6.09
# 3618         house               uppal southend   sector 49   6.75
# 3195         house               uppal southend   sector 49   6.75
# 3643         house  independent house sector 45   sector 40   9.00
# 2497         house                  independent   sector 43   2.25
#
#       price_per_sqft    area  \
# 2122         43066.0  1161.0
# 3341         39062.0  1152.0
# 3030          5160.0  7500.0
# 2335         24214.0  1623.0
# 848          38194.0  1440.0
# 1756         46906.0  1503.0
# 3417         38986.0  3078.0
# 3294         34037.0  2700.0
# 3478         48888.0  4091.0
# 329          25000.0  1800.0
# 1265         45889.0  2700.0
# 589          50000.0  2700.0
# 267          44267.0  4518.0
# 1374          6584.0  4860.0
# 1911         27302.0  1575.0
# 2469         33951.0  3240.0
# 2611          8889.0   900.0
# 2056         34083.0  1467.0
# 65           45833.0  1800.0
# 99           10101.0   495.0
# 288          47804.0  1935.0
# 1047         47167.0  1800.0
# 844          43210.0  2430.0
# 413          40135.0  2367.0
# 815          27461.0  2367.0
# 356          48148.0  2700.0
# 1825         45833.0  1800.0
# 1415         43534.0  2745.0
# 1392         42032.0  2736.0
# 2328         27741.0  2700.0
# 2249          5974.0  5022.0
# 2167          6875.0  3200.0
# 1946         17707.0  4518.0
# 1519         38760.0  1935.0
# 1634         39530.0  2340.0
# 1663         31915.0  2115.0
# 2583         38611.0  1800.0
# 3323         12820.0  1170.0
# 3121         44444.0  2250.0
# 2660         36911.0  1845.0
# 2784         33665.0  1809.0
# 3618         32328.0  2088.0
# 3195         32328.0  2088.0
# 3643         38023.0  2367.0
# 2497          7500.0  3000.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 2122                        Plot area 129(107.86 sq.m.)       21        21
# 3341                        Plot area 128(107.02 sq.m.)       20        20
# 3030  Plot area 1623(150.78 sq.m.)Built Up area: 750...       19        17
# 2335  Plot area 1623(150.78 sq.m.)Built Up area: 162...       19        17
# 848                         Plot area 160(133.78 sq.m.)       18        18
# 1756                        Plot area 167(139.63 sq.m.)       18        18
# 3417                        Plot area 342(285.96 sq.m.)       16        16
# 3294                        Plot area 300(250.84 sq.m.)       16        18
# 3478                        Plot area 500(418.06 sq.m.)       16        16
# 329                         Plot area 200(167.23 sq.m.)       16        16
# 1265                        Plot area 300(250.84 sq.m.)       16        18
# 589                         Plot area 300(250.84 sq.m.)       16        16
# 267                         Plot area 502(419.74 sq.m.)       16        20
# 1374                          Plot area 60(50.17 sq.m.)       14        14
# 1911  Plot area 163(15.14 sq.m.)Built Up area: 145 s...       13        13
# 2469                        Plot area 360(301.01 sq.m.)       13        13
# 2611                          Plot area 100(9.29 sq.m.)       13         6
# 2056                        Plot area 163(136.29 sq.m.)       13        13
# 65    Plot area 210(175.59 sq.m.)Built Up area: 205 ...       12        12
# 99                             Plot area 55(5.11 sq.m.)       12         4
# 288   Plot area 1935(179.77 sq.m.)Built Up area: 700...       12        12
# 1047                        Plot area 200(167.23 sq.m.)       12        12
# 844   Plot area 302(252.51 sq.m.)Built Up area: 300 ...       12        12
# 413                          Plot area 263(219.9 sq.m.)       12        12
# 815                          Plot area 263(219.9 sq.m.)       12        12
# 356                         Plot area 300(250.84 sq.m.)       12        16
# 1825                        Plot area 200(167.23 sq.m.)       12        12
# 1415                        Plot area 305(255.02 sq.m.)       12        12
# 1392                        Plot area 304(254.18 sq.m.)       12        13
# 2328                        Plot area 300(250.84 sq.m.)       12        12
# 2249                          Plot area 62(51.84 sq.m.)       12        12
# 2167                       Plot area 3200(297.29 sq.m.)       12        12
# 1946                        Plot area 502(419.74 sq.m.)       12         4
# 1519                        Plot area 215(179.77 sq.m.)       12        12
# 1634  Plot area 265(221.57 sq.m.)Built Up area: 262 ...       12        12
# 1663                        Plot area 235(196.49 sq.m.)       12        12
# 2583                        Plot area 192(160.54 sq.m.)       12        12
# 3323                         Plot area 130(108.7 sq.m.)       12         9
# 3121                         Plot area 250(23.23 sq.m.)       12        12
# 2660                        Plot area 205(171.41 sq.m.)       12        14
# 2784  Plot area 201(168.06 sq.m.)Built Up area: 180 ...       12        11
# 3618                        Plot area 232(193.98 sq.m.)       12        12
# 3195                         Plot area 232(21.55 sq.m.)       12        12
# 3643  Plot area 2367(219.9 sq.m.)Built Up area: 9000...       12        12
# 2497  Plot area 550(51.1 sq.m.)Built Up area: 3000 s...       11        11
#
#      balcony  floorNum      facing   agePossession  super_built_up_area  \
# 2122      3+       5.0       North  Relatively New                  NaN
# 3341      3+       4.0        East  Relatively New                  NaN
# 3030      3+       5.0  North-West  Relatively New                  NaN
# 2335       3       4.0  North-West  Relatively New                  NaN
# 848       3+       4.0  South-West  Relatively New                  NaN
# 1756      3+       4.0  North-East  Relatively New                  NaN
# 3417      3+       4.0         NaN    New Property                  NaN
# 3294       2       4.0        West    New Property                  NaN
# 3478      3+       4.0         NaN    New Property                  NaN
# 329       3+       4.0       South  Relatively New                  NaN
# 1265      3+       4.0  North-East    New Property                  NaN
# 589       3+       4.0  North-West  Relatively New                  NaN
# 267       3+       4.0  North-East    New Property                  NaN
# 1374      3+       6.0        West  Relatively New                  NaN
# 1911      3+       5.0  North-West  Relatively New                  NaN
# 2469      3+       3.0        East  Relatively New                  NaN
# 2611      3+       3.0       South  Moderately Old                  NaN
# 2056      3+       4.0       North    New Property                  NaN
# 65        3+       4.0        East    New Property                  NaN
# 99         3       4.0         NaN    Old Property                  NaN
# 288       3+       4.0  North-East    New Property                  NaN
# 1047      3+       4.0       North  Relatively New                  NaN
# 844       3+       4.0  North-East  Relatively New                  NaN
# 413       3+       4.0         NaN    New Property                  NaN
# 815       3+       4.0  North-West  Relatively New                  NaN
# 356       3+       4.0  North-East    New Property                  NaN
# 1825      3+       4.0       North    New Property                  NaN
# 1415      3+       4.0        West  Relatively New                  NaN
# 1392      3+       4.0        West  Relatively New                  NaN
# 2328      3+       4.0  South-East  Relatively New                  NaN
# 2249      3+       5.0        West    New Property                  NaN
# 2167      3+       6.0       North    New Property                  NaN
# 1946      3+       3.0       North    Old Property                  NaN
# 1519      3+       4.0        East    New Property                  NaN
# 1634      3+       4.0  North-East    New Property                  NaN
# 1663      3+       3.0        West  Moderately Old                  NaN
# 2583      3+       4.0        East    New Property                  NaN
# 3323       1       3.0        East  Relatively New                  NaN
# 3121      3+       4.0       North  Relatively New                  NaN
# 2660      3+       NaN        East    New Property                  NaN
# 2784      3+       4.0        West  Moderately Old                  NaN
# 3618      3+       3.0       North  Moderately Old                  NaN
# 3195      3+       NaN        West  Moderately Old                  NaN
# 3643       3       4.0  North-West    New Property                  NaN
# 2497      3+       5.0        West    New Property                  NaN
#
#       built_up_area  carpet_area  servant room  study room  pooja room  \
# 2122         1161.0          NaN             1           0           0
# 3341         1152.0          NaN             1           0           0
# 3030         7500.0          NaN             0           1           0
# 2335         1622.0          NaN             1           1           1
# 848          1440.0          NaN             1           0           0
# 1756         1503.0          NaN             0           0           0
# 3417         3078.0          NaN             1           1           1
# 3294         2700.0          NaN             1           0           1
# 3478          500.0          NaN             1           0           0
# 329          1800.0          NaN             0           0           0
# 1265         2700.0          NaN             1           0           1
# 589          2700.0          NaN             1           1           1
# 267          4518.0          NaN             1           1           1
# 1374          540.0          NaN             0           0           0
# 1911          145.0          NaN             0           0           0
# 2469         3240.0          NaN             1           1           1
# 2611          100.0          NaN             1           1           1
# 2056         1467.0          NaN             0           0           1
# 65            205.0        200.0             1           0           1
# 99             55.0          NaN             0           0           0
# 288          7000.0          NaN             1           0           1
# 1047         1800.0          NaN             1           0           1
# 844           300.0        270.0             1           0           1
# 413          2367.0          NaN             0           0           0
# 815          2367.0          NaN             0           1           1
# 356          2700.0          NaN             1           1           1
# 1825         1800.0          NaN             1           0           0
# 1415         2745.0          NaN             1           0           0
# 1392         2736.0          NaN             1           1           1
# 2328         2700.0          NaN             1           1           1
# 2249          558.0          NaN             0           0           0
# 2167         3200.0          NaN             1           0           0
# 1946         4518.0          NaN             1           0           0
# 1519         1935.0          NaN             1           1           1
# 1634          262.0        260.0             1           0           1
# 1663         2115.0          NaN             0           0           0
# 2583         1728.0          NaN             1           0           0
# 3323         1170.0          NaN             1           1           1
# 3121          250.0          NaN             1           1           0
# 2660         1845.0          NaN             1           0           0
# 2784          180.0        150.0             0           0           1
# 3618         2088.0          NaN             1           1           1
# 3195          232.0          NaN             1           1           1
# 3643         9000.0       6000.0             1           0           0
# 2497         3000.0          NaN             0           0           0
#
#       store room  others  furnished_type  luxury_score
# 2122           0       0               2            49
# 3341           0       0               2            22
# 3030           1       0               0            68
# 2335           1       0               0            74
# 848            0       0               2            70
# 1756           0       1               2            57
# 3417           1       0               1             0
# 3294           0       0               1            49
# 3478           0       0               1            31
# 329            0       0               1            20
# 1265           0       0               1            49
# 589            0       1               0            41
# 267            1       0               1           153
# 1374           0       0               2            15
# 1911           0       0               2             7
# 2469           0       0               2           122
# 2611           0       1               0             0
# 2056           0       0               2            91
# 65             0       0               1            40
# 99             0       0               0            15
# 288            0       0               1            43
# 1047           0       0               1            42
# 844            0       0               1            72
# 413            1       0               1            57
# 815            0       0               1            32
# 356            1       0               2           144
# 1825           0       0               1           105
# 1415           0       0               1            21
# 1392           0       0               1            49
# 2328           0       0               1            49
# 2249           0       1               2            20
# 2167           0       0               2            50
# 1946           1       0               0            32
# 1519           1       0               1            72
# 1634           0       1               2            49
# 1663           0       1               0            49
# 2583           1       0               1            73
# 3323           0       1               1           106
# 3121           0       0               1           114
# 2660           0       1               1            40
# 2784           0       0               2            44
# 3618           0       1               1            49
# 3195           0       1               1            49
# 3643           0       0               1            71
# 2497           0       1               2            28

# %%
df = df[df['bedRoom'] <= 10]

# %%
df.shape
# Out:
# (3599, 23)

# %%
plt.figure(figsize = (17, 7))
sns.boxplot(x = df['bedRoom'])
plt.show()

# %%
df['bedRoom'].describe()
# Out:
# count    3599.000000
# mean        3.204223
# std         1.393315
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max        10.000000
# Name: bedRoom, dtype: float64

# %% [markdown]
# ## bathroom

# %%
custom_bins = [0, 3, 6, 9, 12, 15, 18, 21]
sns.displot(df['bathroom'], kde = True, height = 6, aspect = 2, bins = custom_bins)
plt.show()

# %%
plt.figure(figsize = (17, 7))
sns.boxplot(x = df['bathroom'])
plt.show()

# %%
df['bathroom'].describe()
# Out:
# count    3599.000000
# mean        3.271186
# std         1.455407
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max        12.000000
# Name: bathroom, dtype: float64

# %%
df[df['bathroom'] > 10]
# Out:
#      property_type               society     sector  price  price_per_sqft  \
# 1848         house           independent  sector 24  11.00         28902.0
# 2716         house  adani brahma samsara  sector 60  18.02         28200.0
# 3522         house           independent  sector 39   7.00         10000.0
#
#         area                                       areaWithType  bedRoom  \
# 1848  3806.0  Plot area 3806.45(353.63 sq.m.)Built Up area: ...        8
# 2716  6390.0                 Built Up area: 6390 (593.65 sq.m.)        9
# 3522  7000.0  Plot area 350(32.52 sq.m.)Built Up area: 7000 ...       10
#
#       bathroom balcony  floorNum      facing   agePossession  \
# 1848        11      3+       3.0        East    Old Property
# 2716        12      3+       3.0  North-East  Relatively New
# 3522        11      3+       4.0  South-East  Relatively New
#
#       super_built_up_area  built_up_area  carpet_area  servant room  \
# 1848                  NaN         5000.0          NaN             1
# 2716                  NaN         6390.0          NaN             1
# 3522                  NaN         7000.0          NaN             0
#
#       study room  pooja room  store room  others  furnished_type  luxury_score
# 1848           1           1           0       1               1            39
# 2716           0           0           0       0               1           146
# 3522           0           1           0       0               2            38

# %% [markdown]
# these are genuine outliers not data error

# %% [markdown]
# ## Super built up area

# %%
sns.displot(df['super_built_up_area'], kde = True, height = 6, aspect = 2)
plt.show()

# %%
plt.figure(figsize = (17, 7))
sns.boxplot(x = df['super_built_up_area'])
plt.show()

# %%
df['super_built_up_area'].describe()
# Out:
# count     1876.000000
# mean      1924.104771
# std        764.371152
# min         89.000000
# 25%       1477.250000
# 50%       1828.000000
# 75%       2215.000000
# max      10000.000000
# Name: super_built_up_area, dtype: float64

# %%
df[df['super_built_up_area'] > 6000]
# Out:
#      property_type                      society     sector  price  \
# 177           flat       krrish provence estate  sector 54    7.5
# 1168          flat  bestech park view grand spa  sector 81    4.7
#
#       price_per_sqft     area                             areaWithType  \
# 177           7500.0  10000.0  Super Built up area 10000(929.03 sq.m.)
# 1168          6786.0   6926.0   Super Built up area 6926(643.45 sq.m.)
#
#       bedRoom  bathroom balcony  floorNum      facing   agePossession  \
# 177         5         6      3+      23.0  North-East  Relatively New
# 1168        4         4      3+      19.0       North  Relatively New
#
#       super_built_up_area  built_up_area  carpet_area  servant room  \
# 177               10000.0            NaN          NaN             1
# 1168               6926.0            NaN          NaN             1
#
#       study room  pooja room  store room  others  furnished_type  luxury_score
# 177            0           1           0       1               0            49
# 1168           0           0           0       0               1           140

# %% [markdown]
# correct data

# %% [markdown]
# ## built up area

# %%
sns.displot(df['built_up_area'], kde = True, height = 6, aspect = 2)
plt.show()

# %%
plt.figure(figsize = (17, 7))
sns.boxplot(x = df['built_up_area'])
plt.show()

# %%
df[df['built_up_area'] > 10000]
# Out:
#      property_type      society     sector  price  price_per_sqft     area  \
# 1395         house  independent  sector 43   27.5         24366.0  11286.0
#
#                       areaWithType  bedRoom  bathroom balcony  floorNum  \
# 1395  Plot area 1254(1048.5 sq.m.)        6         7      3+       3.0
#
#           facing   agePossession  super_built_up_area  built_up_area  \
# 1395  North-East  Relatively New                  NaN        11286.0
#
#       carpet_area  servant room  study room  pooja room  store room  others  \
# 1395          NaN             1           1           1           0       1
#
#       furnished_type  luxury_score
# 1395               1            42

# %% [markdown]
# ## carpet area

# %%
sns.displot(df['carpet_area'], kde = True, height = 6, aspect = 2)
plt.show()

# %%
plt.figure(figsize = (17, 7))
sns.boxplot(x = df['carpet_area'])
plt.show()

# %%
df[df['carpet_area'] > 10000]
# Out:
#      property_type         society     sector  price  price_per_sqft     area  \
# 1113          flat      godrej air  sector 85    2.5          1379.0   1812.0
# 2412          flat  m3m golfestate  sector 65   13.2         12000.0  11000.0
#
#                             areaWithType  bedRoom  bathroom balcony  floorNum  \
# 1113  Carpet area: 18122 (1683.59 sq.m.)        4         5      3+      16.0
# 2412  Carpet area: 11000 (1021.93 sq.m.)        4         4       3      13.0
#
#           facing   agePossession  super_built_up_area  built_up_area  \
# 1113  North-East       Undefined                  NaN            NaN
# 2412       North  Moderately Old                  NaN            NaN
#
#       carpet_area  servant room  study room  pooja room  store room  others  \
# 1113      18122.0             0           1           1           0       1
# 2412      11000.0             1           0           0           0       0
#
#       furnished_type  luxury_score
# 1113               1            44
# 2412               0            60

# %%
df.loc[1113, 'carpet_area'] = 1812

# %%
df[df['carpet_area'] > 10000]
# Out:
#      property_type         society     sector  price  price_per_sqft     area  \
# 2412          flat  m3m golfestate  sector 65   13.2         12000.0  11000.0
#
#                             areaWithType  bedRoom  bathroom balcony  floorNum  \
# 2412  Carpet area: 11000 (1021.93 sq.m.)        4         4       3      13.0
#
#      facing   agePossession  super_built_up_area  built_up_area  carpet_area  \
# 2412  North  Moderately Old                  NaN            NaN      11000.0
#
#       servant room  study room  pooja room  store room  others  \
# 2412             1           0           0           0       0
#
#       furnished_type  luxury_score
# 2412               0            60

# %%
sns.displot(df['carpet_area'], kde = True, height = 6, aspect = 2)
plt.show()

# %%
plt.figure(figsize = (17, 7))
sns.boxplot(x = df['carpet_area'])
plt.show()

# %% [markdown]
# ## luxury score

# %%
df['luxury_score'].describe()
# Out:
# count    3599.000000
# mean       71.702139
# std        53.242266
# min         0.000000
# 25%        31.000000
# 50%        59.000000
# 75%       110.000000
# max       174.000000
# Name: luxury_score, dtype: float64

# %%
sns.displot(df['luxury_score'], kde = True, height = 6, aspect = 2)
plt.show()

# %%
plt.figure(figsize = (17, 7))
sns.boxplot(x = df['luxury_score'])
plt.show()

# %% [markdown]
# ## price per sqft
# again checking for price per sqft, above we have changed or remove outliers in area columns

# %%
df['price_per_sqft'] = round(df['price']*10000000/df['area'])
# Out:
# C:\Users\Shubham\AppData\Local\Temp\ipykernel_15772\3913081489.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_per_sqft'] = round(df['price']*10000000/df['area'])

# %%
sns.displot(df['price_per_sqft'], kde = True, height = 6, aspect = 2)
plt.show()

# %%
plt.figure(figsize = (17, 7))
sns.boxplot(x = df['price_per_sqft'])
plt.show()

# %%
df[df['price_per_sqft'] > 42000]
# Out:
#      property_type                       society      sector  price  \
# 1057         house  sushant lok 1 builder floors   sector 43   13.0
# 1308         house                   independent   sector 43    9.5
# 2010         house                dlf city plots   sector 26   19.0
# 2485         house                   independent   sector 28   12.0
# 2727         house                   independent   sector 25   13.0
# 2900         house                   independent   sector 55    5.0
# 3359         house                   independent  sector 105    9.9
# 3460         house                   independent   sector 26   20.0
# 3572         house                   independent   sector 26   19.0
#
#       price_per_sqft    area  \
# 1057         48148.0  2700.0
# 1308         42222.0  2250.0
# 2010         42054.0  4518.0
# 2485         42194.0  2844.0
# 2727         45710.0  2844.0
# 2900         44444.0  1125.0
# 3359         49500.0  2000.0
# 3460         44444.0  4500.0
# 3572         42222.0  4500.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 1057                        Plot area 300(250.84 sq.m.)        3         3
# 1308  Plot area 302(252.51 sq.m.)Built Up area: 300 ...        5         5
# 2010                        Plot area 502(419.74 sq.m.)        6         6
# 2485                        Plot area 316(264.22 sq.m.)        4         5
# 2727                        Plot area 316(264.22 sq.m.)        6         8
# 2900  Plot area 125(104.52 sq.m.)Built Up area: 115 ...        9         9
# 3359  Built Up area: 2000 (185.81 sq.m.)Carpet area:...        2         2
# 3460                        Plot area 500(418.06 sq.m.)        5         7
# 3572                        Plot area 500(418.06 sq.m.)        6         8
#
#      balcony  floorNum      facing   agePossession  super_built_up_area  \
# 1057      3+       4.0       North    New Property                  NaN
# 1308      3+       2.0  North-East  Relatively New                  NaN
# 2010       3       2.0        East  Relatively New                  NaN
# 2485      3+       4.0        East  Relatively New                  NaN
# 2727      3+       NaN         NaN  Relatively New                  NaN
# 2900      3+       5.0        East    New Property                  NaN
# 3359       2       3.0       North       Undefined                  NaN
# 3460      3+       3.0        West  Relatively New                  NaN
# 3572      3+       3.0        East  Moderately Old                  NaN
#
#       built_up_area  carpet_area  servant room  study room  pooja room  \
# 1057         2700.0          NaN             0           0           1
# 1308          300.0        250.0             1           0           1
# 2010         4518.0          NaN             1           1           0
# 2485         2844.0          NaN             1           0           1
# 2727         2844.0          NaN             1           1           1
# 2900          115.0        100.0             0           0           0
# 3359         2000.0       1800.0             0           0           0
# 3460         4500.0          NaN             1           0           1
# 3572         4500.0          NaN             1           1           1
#
#       store room  others  furnished_type  luxury_score
# 1057           0       0               1             7
# 1308           0       0               1            88
# 2010           0       0               1           121
# 2485           1       0               1            60
# 2727           1       0               2             0
# 2900           0       1               1            44
# 3359           0       0               0             0
# 3460           0       0               2            97
# 3572           1       0               1           103

# %%
x = df[df['price_per_sqft'] <= 20000]
(x['area']/x['bedRoom']).quantile(0.05)
# Out:
# np.float64(250.25)

# %%
df[(df['area']/df['bedRoom']) < 250]
# Out:
#      property_type                  society      sector  price  \
# 3             flat  signature global solera  sector 107   0.27
# 30           house                 shivpuri    sector 7   2.80
# 47           house              independent     manesar   1.10
# 56            flat  signature global solera  sector 107   0.28
# 69           house              independent   sector 23   3.65
# ...            ...                      ...         ...    ...
# 3640          flat            prime habitat   sector 99   0.27
# 3657         house              independent    sector 3   0.80
# 3660          flat               mvn athens  sohna road   0.27
# 3661         house              independent    sector 5   1.10
# 3662         house            sector 38 rwa   sector 38   1.40
#
#       price_per_sqft    area  \
# 3             5521.0   489.0
# 30           12444.0  2250.0
# 47            6173.0  1782.0
# 56            5833.0   480.0
# 69           23443.0  1557.0
# ...              ...     ...
# 3640          5433.0   497.0
# 3657          8155.0   981.0
# 3660          5895.0   458.0
# 3661         10000.0  1100.0
# 3662         23932.0   585.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 3                        Carpet area: 489 (45.43 sq.m.)        2         2
# 30                         Plot area 2250(209.03 sq.m.)       10         7
# 47                         Plot area 1782(165.55 sq.m.)        8         8
# 56                       Carpet area: 489 (45.43 sq.m.)        2         2
# 69                          Plot area 173(144.65 sq.m.)        9         9
# ...                                                 ...      ...       ...
# 3640                     Carpet area: 497 (46.17 sq.m.)        2         2
# 3657                         Plot area 109(91.14 sq.m.)        5         4
# 3660                  Carpet area: 457.81 (42.53 sq.m.)        2         2
# 3661  Built Up area: 1100 (102.19 sq.m.)Carpet area:...        5         4
# 3662  Plot area 65(54.35 sq.m.)Built Up area: 62 sq....        8         8
#
#      balcony  floorNum      facing   agePossession  super_built_up_area  \
# 3          2       0.0  North-East  Relatively New                  NaN
# 30         3       1.0         NaN    Old Property                  NaN
# 47         0       1.0         NaN    New Property                  NaN
# 56         2       0.0  North-East  Relatively New                  NaN
# 69        3+       3.0        West    New Property                  NaN
# ...      ...       ...         ...             ...                  ...
# 3640       1       4.0  North-East    New Property                  NaN
# 3657       1       2.0         NaN  Moderately Old                  NaN
# 3660       1       4.0  South-East  Relatively New                  NaN
# 3661       2       1.0        East       Undefined                  NaN
# 3662       3       4.0        East  Moderately Old                  NaN
#
#       built_up_area  carpet_area  servant room  study room  pooja room  \
# 3               NaN   489.000000             0           0           0
# 30           2250.0          NaN             1           1           1
# 47           1782.0          NaN             0           0           0
# 56              NaN   489.000000             0           0           0
# 69           1557.0          NaN             1           0           1
# ...             ...          ...           ...         ...         ...
# 3640            NaN   497.000000             0           0           0
# 3657          981.0          NaN             0           0           0
# 3660            NaN   457.788667             0           0           0
# 3661         1100.0   900.000000             0           0           0
# 3662           62.0    60.000000             0           0           0
#
#       store room  others  furnished_type  luxury_score
# 3              0       0               0            45
# 30             0       1               1             0
# 47             0       0               0             0
# 56             0       0               0            45
# 69             0       0               1           116
# ...          ...     ...             ...           ...
# 3640           0       0               0             7
# 3657           0       0               0             0
# 3660           0       1               1            35
# 3661           0       0               0             0
# 3662           0       1               1            40
#
# [187 rows x 23 columns]

# %% [markdown]
# area is too much as compared to bedroom eg. area 565 having bedroom 5, which is considered as a data error

# %%
sns.lmplot(data = df, x = 'area', y = 'bedRoom', height = 7, aspect = 2)
plt.show()

# %%
df['area_room_ratio'] = df['area']/df['bedRoom']
# Out:
# C:\Users\Shubham\AppData\Local\Temp\ipykernel_15772\465686754.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['area_room_ratio'] = df['area']/df['bedRoom']

# %%
df.sort_values(by = 'area_room_ratio', ascending = True).head(10)
# Out:
#      property_type                          society      sector  price  \
# 683          house                      independent   sector 28   0.75
# 2344         house  ashok vihar phase iii extension    sector 5   0.40
# 2943         house                            ansal   sector 43   1.85
# 878          house                      independent  sector 105   0.60
# 609          house                      independent    sector 6   0.50
# 3212         house                      independent   sector 88   0.32
# 3004         house                      independent    sector 8   0.49
# 3662         house                    sector 38 rwa   sector 38   1.40
# 3281         house            rajendra park gurgaon  sector 105   0.37
# 2229         house                         ss omnia   sector 86   0.42
#
#       price_per_sqft   area  \
# 683          20833.0  360.0
# 2344          8889.0  450.0
# 2943         34259.0  540.0
# 878          11111.0  540.0
# 609          13889.0  360.0
# 3212         22069.0  145.0
# 3004         11239.0  436.0
# 3662         23932.0  585.0
# 3281         10278.0  360.0
# 2229          9333.0  450.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 683                           Plot area 40(33.45 sq.m.)        7         4
# 2344                          Plot area 50(41.81 sq.m.)        7         4
# 2943                           Plot area 60(5.57 sq.m.)        8         8
# 878                           Plot area 60(50.17 sq.m.)        8         4
# 609                           Plot area 40(33.45 sq.m.)        5         3
# 3212                   Built Up area: 145 (13.47 sq.m.)        2         2
# 3004                         Plot area 360(33.45 sq.m.)        6         3
# 3662  Plot area 65(54.35 sq.m.)Built Up area: 62 sq....        8         8
# 3281                         Plot area 360(33.45 sq.m.)        4         3
# 2229                           Plot area 50(4.65 sq.m.)        5         3
#
#      balcony  floorNum      facing   agePossession  super_built_up_area  \
# 683       3+       4.0         NaN  Moderately Old                  NaN
# 2344      3+       4.0         NaN    New Property                  NaN
# 2943      3+       5.0  North-West  Relatively New                  NaN
# 878        3       3.0        West    New Property                  NaN
# 609        3       3.0         NaN    Old Property                  NaN
# 3212       0       3.0         NaN       Undefined                  NaN
# 3004       2       3.0        East  Moderately Old                  NaN
# 3662       3       4.0        East  Moderately Old                  NaN
# 3281       2       3.0        East  Relatively New                  NaN
# 2229       2       3.0         NaN  Relatively New                  NaN
#
#       built_up_area  carpet_area  servant room  study room  pooja room  \
# 683           360.0          NaN             0           0           0
# 2344          450.0          NaN             0           0           1
# 2943           60.0          NaN             0           0           0
# 878           540.0          NaN             0           0           0
# 609           360.0          NaN             0           0           0
# 3212          145.0          NaN             0           0           0
# 3004          360.0          NaN             0           0           0
# 3662           62.0         60.0             0           0           0
# 3281          360.0          NaN             0           0           0
# 2229           50.0          NaN             0           0           0
#
#       store room  others  furnished_type  luxury_score  area_room_ratio
# 683            0       0               0             7        51.428571
# 2344           0       0               0             7        64.285714
# 2943           0       0               0            53        67.500000
# 878            0       0               0            17        67.500000
# 609            0       0               0             0        72.000000
# 3212           0       0               0             0        72.500000
# 3004           0       0               0             8        72.666667
# 3662           0       1               1            40        73.125000
# 3281           0       0               0             0        90.000000
# 2229           0       0               0             0        90.000000

# %%
df[df['area_room_ratio'] < 100]
# Out:
#      property_type                          society      sector  price  \
# 280          house                      independent    sector 5   0.50
# 609          house                      independent    sector 6   0.50
# 683          house                      independent   sector 28   0.75
# 806          house                      independent  sector 104   0.45
# 878          house                      independent  sector 105   0.60
# 910          house                    rattan garden    sector 7   0.83
# 1822         house                      independent    sector 7   0.89
# 2229         house                         ss omnia   sector 86   0.42
# 2344         house  ashok vihar phase iii extension    sector 5   0.40
# 2653         house                      independent   sector 28   0.45
# 2943         house                            ansal   sector 43   1.85
# 2968         house                      independent    sector 4   0.50
# 3004         house                      independent    sector 8   0.49
# 3061         house                   not applicable    sector 4   0.51
# 3094         house                      independent    sector 9   0.42
# 3212         house                      independent   sector 88   0.32
# 3281         house            rajendra park gurgaon  sector 105   0.37
# 3420         house                        jacobpura   sector 12   0.53
# 3541         house                        rk excelo   sector 12   0.60
# 3662         house                    sector 38 rwa   sector 38   1.40
#
#       price_per_sqft   area  \
# 280          11111.0  450.0
# 609          13889.0  360.0
# 683          20833.0  360.0
# 806          12162.0  370.0
# 878          11111.0  540.0
# 910          17585.0  472.0
# 1822         18658.0  477.0
# 2229          9333.0  450.0
# 2344          8889.0  450.0
# 2653         10000.0  450.0
# 2943         34259.0  540.0
# 2968         10482.0  477.0
# 3004         11239.0  436.0
# 3061         14167.0  360.0
# 3094          9333.0  450.0
# 3212         22069.0  145.0
# 3281         10278.0  360.0
# 3420         14601.0  363.0
# 3541         13333.0  450.0
# 3662         23932.0  585.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 280                          Plot area 450(41.81 sq.m.)        5         3
# 609                           Plot area 40(33.45 sq.m.)        5         3
# 683                           Plot area 40(33.45 sq.m.)        7         4
# 806   Plot area 370(34.37 sq.m.)Carpet area: 1500 sq...        4         4
# 878                           Plot area 60(50.17 sq.m.)        8         4
# 910                      Carpet area: 472 (43.85 sq.m.)        5         3
# 1822                         Plot area 477(44.31 sq.m.)        5         3
# 2229                           Plot area 50(4.65 sq.m.)        5         3
# 2344                          Plot area 50(41.81 sq.m.)        7         4
# 2653                     Built Up area: 50 (4.65 sq.m.)        5         3
# 2943                           Plot area 60(5.57 sq.m.)        8         8
# 2968                    Built Up area: 53 (44.31 sq.m.)        5         3
# 3004                         Plot area 360(33.45 sq.m.)        6         3
# 3061                          Plot area 40(33.45 sq.m.)        4         4
# 3094                   Built Up area: 450 (41.81 sq.m.)        5         3
# 3212                   Built Up area: 145 (13.47 sq.m.)        2         2
# 3281                         Plot area 360(33.45 sq.m.)        4         3
# 3420                         Plot area 360(33.45 sq.m.)        4         4
# 3541  Plot area 50(4.65 sq.m.)Built Up area: 30 sq.f...        5         3
# 3662  Plot area 65(54.35 sq.m.)Built Up area: 62 sq....        8         8
#
#      balcony  floorNum      facing   agePossession  super_built_up_area  \
# 280        3       3.0         NaN  Moderately Old                  NaN
# 609        3       3.0         NaN    Old Property                  NaN
# 683       3+       4.0         NaN  Moderately Old                  NaN
# 806        2       4.0       North  Moderately Old                  NaN
# 878        3       3.0        West    New Property                  NaN
# 910        2       3.0        East       Undefined                  NaN
# 1822       2       2.0        East    Old Property                  NaN
# 2229       2       3.0         NaN  Relatively New                  NaN
# 2344      3+       4.0         NaN    New Property                  NaN
# 2653       0       1.0         NaN       Undefined                  NaN
# 2943      3+       5.0  North-West  Relatively New                  NaN
# 2968       0       1.0         NaN       Undefined                  NaN
# 3004       2       3.0        East  Moderately Old                  NaN
# 3061       3       4.0         NaN    New Property                  NaN
# 3094       2       2.0         NaN       Undefined                  NaN
# 3212       0       3.0         NaN       Undefined                  NaN
# 3281       2       3.0        East  Relatively New                  NaN
# 3420       2       3.0        East  Relatively New                  NaN
# 3541       2       3.0       North  Moderately Old                  NaN
# 3662       3       4.0        East  Moderately Old                  NaN
#
#       built_up_area  carpet_area  servant room  study room  pooja room  \
# 280           450.0          NaN             0           0           0
# 609           360.0          NaN             0           0           0
# 683           360.0          NaN             0           0           0
# 806             NaN       1500.0             0           0           0
# 878           540.0          NaN             0           0           0
# 910             NaN        472.0             0           0           0
# 1822          477.0          NaN             0           0           0
# 2229           50.0          NaN             0           0           0
# 2344          450.0          NaN             0           0           1
# 2653           50.0          NaN             0           0           0
# 2943           60.0          NaN             0           0           0
# 2968           53.0          NaN             0           0           0
# 3004          360.0          NaN             0           0           0
# 3061          360.0          NaN             0           0           0
# 3094          450.0          NaN             0           0           0
# 3212          145.0          NaN             0           0           0
# 3281          360.0          NaN             0           0           0
# 3420          360.0          NaN             0           0           0
# 3541           30.0         15.0             0           0           0
# 3662           62.0         60.0             0           0           0
#
#       store room  others  furnished_type  luxury_score  area_room_ratio
# 280            0       0               0             0        90.000000
# 609            0       0               0             0        72.000000
# 683            0       0               0             7        51.428571
# 806            0       0               1             7        92.500000
# 878            0       0               0            17        67.500000
# 910            0       0               0             0        94.400000
# 1822           0       0               0             8        95.400000
# 2229           0       0               0             0        90.000000
# 2344           0       0               0             7        64.285714
# 2653           0       0               0             0        90.000000
# 2943           0       0               0            53        67.500000
# 2968           0       0               0             0        95.400000
# 3004           0       0               0             8        72.666667
# 3061           0       0               0             0        90.000000
# 3094           0       0               0             0        90.000000
# 3212           0       0               0             0        72.500000
# 3281           0       0               0             0        90.000000
# 3420           0       0               0             0        90.750000
# 3541           0       1               0             0        90.000000
# 3662           0       1               1            40        73.125000

# %%
df[df['area_room_ratio'] < 100].shape
# Out:
# (0, 24)

# %% [markdown]
# area to room ratio is less than 100, these are outliers drop these rows

# %%
df = df[df['area_room_ratio'] > 100]

# %%
outliers_df = df[(df['area_room_ratio'] < 250) & (df['bedRoom'] > 3)]

# %%
outliers_df['bedRoom'] = round(outliers_df['bedRoom']/outliers_df['floorNum'])
# Out:
# C:\Users\Shubham\AppData\Local\Temp\ipykernel_15772\3450078040.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outliers_df['bedRoom'] = round(outliers_df['bedRoom']/outliers_df['floorNum'])

# %%
df.update(outliers_df)

# %%
df['area_room_ratio'] = df['area']/df['bedRoom']
# Out:
# C:\Users\Shubham\AppData\Local\Temp\ipykernel_15772\465686754.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['area_room_ratio'] = df['area']/df['bedRoom']

# %%
df[(df['area_room_ratio'] < 250) & (df['bedRoom'] > 4)]
# Out:
#      property_type               society      sector  price  price_per_sqft  \
# 30           house              shivpuri    sector 7   2.80         12444.0
# 47           house           independent     manesar   1.10          6173.0
# 127          house           independent   sector 11   3.50         15556.0
# 208          house           independent   sector 88   0.32          5664.0
# 1043         house           independent    sector 1   0.65          6500.0
# 1185         house           independent    sector 7   1.16         11717.0
# 1225         house           independent  sector 105   1.10         12222.0
# 1258         house  bhim nagar, sector 6    sector 6   0.85         14096.0
# 2439         house           independent   sector 12   2.50         13889.0
# 2656         house           independent    sector 5   0.85          9444.0
# 3318         house           independent   sector 23   0.98          9074.0
# 3511         house           independent     manesar   0.80          6667.0
# 3661         house           independent    sector 5   1.10         10000.0
#
#         area                                       areaWithType  bedRoom  \
# 30    2250.0                       Plot area 2250(209.03 sq.m.)       10
# 47    1782.0                       Plot area 1782(165.55 sq.m.)        8
# 127   2250.0                 Built Up area: 2250 (209.03 sq.m.)       10
# 208    565.0                   Built Up area: 565 (52.49 sq.m.)        5
# 1043  1000.0                     Carpet area: 1000 (92.9 sq.m.)        6
# 1185   990.0                     Carpet area: 110 (91.97 sq.m.)        5
# 1225   900.0                     Carpet area: 900 (83.61 sq.m.)        6
# 1258   603.0                           Plot area 67(6.22 sq.m.)        5
# 2439  1800.0                       Plot area 1800(167.23 sq.m.)        9
# 2656   900.0                     Carpet area: 900 (83.61 sq.m.)        5
# 3318  1080.0                    Carpet area: 120 (100.34 sq.m.)        9
# 3511  1200.0                       Plot area 1200(111.48 sq.m.)        8
# 3661  1100.0  Built Up area: 1100 (102.19 sq.m.)Carpet area:...        5
#
#       bathroom balcony  floorNum      facing   agePossession  \
# 30           7       3       1.0         NaN    Old Property
# 47           8       0       1.0         NaN    New Property
# 127          1       0       1.0         NaN    New Property
# 208          1       0       1.0         NaN       Undefined
# 1043         2       3       1.0         NaN       Undefined
# 1185         4       2       1.0  North-East       Undefined
# 1225         4       1       1.0  South-West       Undefined
# 1258         2       2       1.0         NaN    Old Property
# 2439         5       2       1.0  South-East    Old Property
# 2656         3       3       1.0         NaN       Undefined
# 3318         4       3       1.0       South       Undefined
# 3511         8       2       1.0         NaN  Relatively New
# 3661         4       2       1.0        East       Undefined
#
#       super_built_up_area  built_up_area  carpet_area  servant room  \
# 30                    NaN         2250.0          NaN             1
# 47                    NaN         1782.0          NaN             0
# 127                   NaN         2250.0          NaN             0
# 208                   NaN          565.0          NaN             0
# 1043                  NaN            NaN       1000.0             0
# 1185                  NaN            NaN        110.0             0
# 1225                  NaN            NaN        900.0             0
# 1258                  NaN           67.0          NaN             0
# 2439                  NaN         1800.0          NaN             0
# 2656                  NaN            NaN        900.0             0
# 3318                  NaN            NaN        120.0             0
# 3511                  NaN         1200.0          NaN             0
# 3661                  NaN         1100.0        900.0             0
#
#       study room  pooja room  store room  others  furnished_type  \
# 30             1           1           0       1               1
# 47             0           0           0       0               0
# 127            0           0           0       0               0
# 208            0           0           0       0               0
# 1043           0           0           0       0               0
# 1185           0           0           0       0               0
# 1225           0           0           0       0               0
# 1258           0           1           0       0               0
# 2439           0           1           0       0               0
# 2656           0           0           0       0               0
# 3318           0           0           0       0               0
# 3511           0           0           0       0               0
# 3661           0           0           0       0               0
#
#       luxury_score  area_room_ratio
# 30               0       225.000000
# 47               0       222.750000
# 127              0       225.000000
# 208              0       113.000000
# 1043             0       166.666667
# 1185             0       198.000000
# 1225             0       150.000000
# 1258            29       120.600000
# 2439             8       200.000000
# 2656             0       180.000000
# 3318             0       120.000000
# 3511             0       150.000000
# 3661             0       220.000000

# %%
df[(df['area_room_ratio'] < 250) & (df['bedRoom'] > 4)].shape
# Out:
# (13, 24)

# %%
df = df[~((df['area_room_ratio'] < 250) & (df['bedRoom'] > 4))]

# %%
sns.lmplot(data = df, x = 'area', y = 'bedRoom', height = 7, aspect = 2)
plt.show()

# %%
df.shape
# Out:
# (3566, 24)

# %%
df.sample(20)
# Out:
#      property_type                           society      sector  price  \
# 812           flat           signature global solera  sector 107   0.28
# 511           flat            guru gram haryana cghs   sector 56   1.39
# 3248         house                    unitech espace   sector 50   7.45
# 1921          flat           signature global solera  sector 107   0.25
# 145           flat                    dlf park place   sector 54   6.75
# 1570          flat                   kiran residency   sector 56   1.50
# 3239          flat      krisumi waterfall residences   sector 36   4.10
# 2841         house                    ss aaron ville   sector 49   6.75
# 1136          flat                    tulip monsella   sector 53   5.60
# 459          house                       independent    sector 9   1.25
# 660          house                       independent   sector 56   7.50
# 1335          flat                     godrej summit  sector 104   1.35
# 2187          flat  emaar mgf emerald floors premier   sector 65   2.35
# 3169          flat               smart world orchard   sector 61   1.65
# 1776          flat               smart world orchard   sector 61   2.00
# 3584          flat           signature global park 4   sector 36   0.85
# 1088          flat              shree vardhman flora   sector 90   0.90
# 3349          flat                 awho sispal vihar   sector 49   2.00
# 178           flat             elan the presidential  sector 106   3.90
# 3144          flat      krisumi waterfall residences   sector 36   3.65
#
#       price_per_sqft    area  \
# 812           5833.0   480.0
# 511           8424.0  1650.0
# 3248         34491.0  2160.0
# 1921          7862.0   318.0
# 145          24963.0  2704.0
# 1570          7500.0  2000.0
# 3239         15501.0  2645.0
# 2841         15000.0  4500.0
# 1136         19364.0  2892.0
# 459           8735.0  1431.0
# 660          23148.0  3240.0
# 1335          5015.0  2692.0
# 2187         14242.0  1650.0
# 3169         13750.0  1200.0
# 1776         12912.0  1549.0
# 3584         11333.0   750.0
# 1088          4615.0  1950.0
# 3349          7262.0  2754.0
# 178          15918.0  2450.0
# 3144         14381.0  2538.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 812                      Carpet area: 489 (45.43 sq.m.)        2         2
# 511   Super Built up area 1850(171.87 sq.m.)Built Up...        3         2
# 3248  Plot area 240(200.67 sq.m.)Built Up area: 4500...        4         4
# 1921                   Built Up area: 318 (29.54 sq.m.)        1         1
# 145   Super Built up area 2704(251.21 sq.m.)Carpet a...        4         4
# 1570  Super Built up area 2000(185.81 sq.m.)Built Up...        3         3
# 3239                   Carpet area: 2538 (235.79 sq.m.)        3         4
# 2841                 Built Up area: 4500 (418.06 sq.m.)        5         4
# 1136             Super Built up area 2892(268.68 sq.m.)        3         3
# 459                         Plot area 159(132.94 sq.m.)        3         6
# 660                         Plot area 360(301.01 sq.m.)        8         8
# 1335                   Carpet area: 2692 (250.09 sq.m.)        4         5
# 2187  Built Up area: 1650 (153.29 sq.m.)Carpet area:...        3         3
# 3169                   Carpet area: 1200 (111.48 sq.m.)        2         2
# 1776                   Carpet area: 1549 (143.91 sq.m.)        3         3
# 3584                     Carpet area: 750 (69.68 sq.m.)        3         2
# 1088             Super Built up area 1950(181.16 sq.m.)        3         4
# 3349             Super Built up area 2754(255.85 sq.m.)        4         3
# 178                  Built Up area: 2450 (227.61 sq.m.)        3         3
# 3144             Super Built up area 2538(235.79 sq.m.)        3         3
#
#      balcony  floorNum      facing       agePossession  super_built_up_area  \
# 812        2      11.0       South      Relatively New                  NaN
# 511        3       6.0       South        Old Property               1850.0
# 3248       3       3.0         NaN        Old Property                  NaN
# 1921       0       0.0         NaN           Undefined                  NaN
# 145        2       8.0       North      Moderately Old               2704.0
# 1570      3+       4.0       North      Relatively New               2000.0
# 3239       3      30.0         NaN        New Property                  NaN
# 2841       2       2.0       North        New Property                  NaN
# 1136      3+       1.0         NaN           Undefined               2892.0
# 459       3+       3.0         NaN        Old Property                  NaN
# 660       3+       3.0  North-East      Relatively New                  NaN
# 1335      3+       0.0  South-East      Relatively New                  NaN
# 2187       3       2.0  South-West      Relatively New                  NaN
# 3169       2       1.0         NaN  Under Construction                  NaN
# 1776       2       3.0         NaN        New Property                  NaN
# 3584       3       1.0         NaN        New Property                  NaN
# 1088       3       4.0  South-West      Relatively New               1950.0
# 3349      3+       4.0         NaN        Old Property               2754.0
# 178        0      20.0         NaN           Undefined                  NaN
# 3144       2      17.0        East        New Property               2538.0
#
#       built_up_area  carpet_area  servant room  study room  pooja room  \
# 812             NaN        489.0             0           0           0
# 511          1750.0       1650.0             1           0           1
# 3248         4500.0       4000.0             1           0           0
# 1921          318.0          NaN             0           0           0
# 145             NaN       1534.0             1           0           0
# 1570         1900.0       1800.0             1           0           0
# 3239            NaN       2538.0             0           1           0
# 2841         4500.0          NaN             0           0           0
# 1136            NaN          NaN             0           0           0
# 459          1431.0          NaN             0           0           0
# 660          3240.0          NaN             1           1           1
# 1335            NaN       2692.0             1           1           1
# 2187         1650.0       1200.0             1           1           0
# 3169            NaN       1200.0             0           1           0
# 1776            NaN       1549.0             0           0           0
# 3584            NaN        750.0             0           0           0
# 1088            NaN          NaN             1           0           0
# 3349            NaN          NaN             0           0           0
# 178          2450.0          NaN             0           0           0
# 3144            NaN          NaN             0           0           0
#
#       store room  others  furnished_type  luxury_score  area_room_ratio
# 812            0       0               0            45       240.000000
# 511            0       0               1            89       550.000000
# 3248           0       0               1            59       540.000000
# 1921           0       0               0            55       318.000000
# 145            0       0               2           135       676.000000
# 1570           0       0               1           126       666.666667
# 3239           0       0               2            49       881.666667
# 2841           0       1               0            49       900.000000
# 1136           0       0               0            42       964.000000
# 459            0       0               0             0       477.000000
# 660            0       0               2            42       405.000000
# 1335           1       0               0            88       673.000000
# 2187           0       0               0           158       550.000000
# 3169           0       0               0            16       600.000000
# 1776           0       1               0            61       516.333333
# 3584           0       0               0            33       250.000000
# 1088           0       0               0           165       650.000000
# 3349           0       0               0            65       688.500000
# 178            0       0               0            66       816.666667
# 3144           0       0               0            31       846.000000

# %%
df.to_csv('gurgaon-outlier-treated.csv', index = False)
